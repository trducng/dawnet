# %% [markdown]
# Steps:
#
# - Search for texts that have refusal. Minimally modify the text to get a version that doesn't trigger refusal.
# - Pick a layer.
# - Get the difference between the refusal and non-refusal text.
# - Apply this difference on other texts as well.
